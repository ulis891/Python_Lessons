# %%
import matplotlib.pyplot as plt

# %%
import random as r

# %%
f = lambda x: r.randint(1, 10)

# %%
points = list(map(f, range(1,10)))
points
# Out:
# [7, 8, 4, 2, 8, 2, 6, 10, 1]

# %%
plt.plot(points, 'ro')

# %%
plt.plot(points)
plt.show()

# %%
x = list(map(f, range(1, 10)))
y = list(map(f, range(1, 10)))
print(x)
print(y)
plt.plot(x, y)
plt.show()
# Out:
# [4, 9, 8, 4, 1, 5, 9, 6, 8]
# [2, 1, 1, 3, 7, 3, 2, 9, 3]

# %%
from sympy import *
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')

# %%
f = x + 2022
f
# Out:
# x + 2022

# %%
f.subs(x, 77)
# Out:
# 2099

# %%
f.subs(x, -210)
# Out:
# 1812

# %%
plot(f)

# %%
g = sin(x+x)/x
plot(g)
